# %%
nome = input("Digite o seu nome: ")
print(nome)
# Out:
# Digite o seu nome: caio
# caio

# %%
z =[3,8,9]
z[0] = 7
z
# Out:
# [7, 8, 9]

# %%
a = [81,82,83]
b = a[:]
print(b)
print(a==b)
print(a is b)
b[0] = 5
print(a)
print(b)
# Out:
# [81, 82, 83]
# True
# False
# [81, 82, 83]
# [5, 82, 83]

# %%
lista = ['a','b','c','d','e','f']
print(lista[1:3])
print(lista[:4])
print(lista[3:])
print(lista[:])
# Out:
# ['b', 'c']
# ['a', 'b', 'c', 'd']
# ['d', 'e', 'f']
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
a = [1,2,3]
b = a[:]
b[0] = 5
#print(a[3])

# %%
sol = True
dinheiro = True
if sol == True and dinheiro == True:
  print('Praia')
else:
  print('Netflix')
# Out:
# Praia

# %%
sol = input("Está fazendo sol? ")
dinheiro = input("tem dinheiros? ")
if sol == 'sim'  and  dinheiro == 'sim':
  print('Praia')
else:
  print('Netflix')
# Out:
# Está fazendo sol? sim
# tem dinheiros? sim
# Praia

# %%
for elemento in 'string':
  print(f'estamos no elemento {elemento}')
# Out:
# estamos no elemento s
# estamos no elemento t
# estamos no elemento r
# estamos no elemento i
# estamos no elemento n
# estamos no elemento g

# %%
for elemento in range(len('string')):
  print(f'estamos no elemento {elemento}')
# Out:
# estamos no elemento 0
# estamos no elemento 1
# estamos no elemento 2
# estamos no elemento 3
# estamos no elemento 4
# estamos no elemento 5
