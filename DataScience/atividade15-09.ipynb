# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#escala aproximada em milhôes
# url = https://www.jbox.com.br/2023/05/31/oricon-libera-ranking-parcial-de-mangas-e-novels-mais-vendidos-em-2023/
mangas_mais_vendidos = {
    "ONE PIECE": 10.364,
    "JUJUTSU KAISEN": 12.282,
    "TOKYO REVENGERS": 11.048,
    "SPY×FAMILY": 10.6001,
    "MY HERO ACADEMIA": 5.353,
    "BLUELOCK": 8.046,
    "CHAINSAW MAN": 4.492,
    "SLAM DUNK": 4.199,
    "COTE": 4.102,
    "KINGDOM": 3.968,
    "DRAGON BALL SUPER": 3.872,
    "MASHLE": 3.836,
    "KNY": 3.766,
    "TPN": 3.745,
    "COMIC BOOK": 3.737,
    "GOHS": 3.686,
    "BORUTO": 3.656,
    "THE PROMISED NEVERLAND": 3.647,
}

# %%
mangas = pd.Series(mangas_mais_vendidos)
mangas
# Out:
# ONE PIECE                 10.3640
# JUJUTSU KAISEN            12.2820
# TOKYO REVENGERS           11.0480
# SPY×FAMILY                10.6001
# MY HERO ACADEMIA           5.3530
# BLUELOCK                   8.0460
# CHAINSAW MAN               4.4920
# SLAM DUNK                  4.1990
# COTE                       4.1020
# KINGDOM                    3.9680
# DRAGON BALL SUPER          3.8720
# MASHLE                     3.8360
# KNY                        3.7660
# TPN                        3.7450
# COMIC BOOK                 3.7370
# GOHS                       3.6860
# BORUTO                     3.6560
# THE PROMISED NEVERLAND     3.6470
# dtype: float64

# %%
mangas = [str(i) for i in mangas_mais_vendidos]
mangas
# Out:
# ['ONE PIECE',
#  'JUJUTSU KAISEN',
#  'TOKYO REVENGERS',
#  'SPY×FAMILY',
#  'MY HERO ACADEMIA',
#  'BLUELOCK',
#  'CHAINSAW MAN',
#  'SLAM DUNK',
#  'COTE',
#  'KINGDOM',
#  'DRAGON BALL SUPER',
#  'MASHLE',
#  'KNY',
#  'TPN',
#  'COMIC BOOK',
#  'GOHS',
#  'BORUTO',
#  'THE PROMISED NEVERLAND']

# %%
copias = []
for j in mangas_mais_vendidos:
    copias.append(mangas_mais_vendidos[j])
copias
# Out:
# [10.364,
#  12.282,
#  11.048,
#  10.6001,
#  5.353,
#  8.046,
#  4.492,
#  4.199,
#  4.102,
#  3.968,
#  3.872,
#  3.836,
#  3.766,
#  3.745,
#  3.737,
#  3.686,
#  3.656,
#  3.647]

# %%
dados = pd.Series(copias,index=mangas)
dados
# Out:
# ONE PIECE                 10.3640
# JUJUTSU KAISEN            12.2820
# TOKYO REVENGERS           11.0480
# SPY×FAMILY                10.6001
# MY HERO ACADEMIA           5.3530
# BLUELOCK                   8.0460
# CHAINSAW MAN               4.4920
# SLAM DUNK                  4.1990
# COTE                       4.1020
# KINGDOM                    3.9680
# DRAGON BALL SUPER          3.8720
# MASHLE                     3.8360
# KNY                        3.7660
# TPN                        3.7450
# COMIC BOOK                 3.7370
# GOHS                       3.6860
# BORUTO                     3.6560
# THE PROMISED NEVERLAND     3.6470
# dtype: float64

# %%
dados.plot(kind='bar')
#conclusão que os aqueles que tem um destaque e uma divulgação maior tendem a vender mais.
# Out:
# <Axes: >
